# %%
import pandas as pd
import os

# %%
baseDir = '/Users/mcassettix/Documents/csv_files'
files = os.listdir(baseDir)

# %%
from itertools import chain
def list_join(*lists):
    tot_df = pd.DataFrame()
    for ll in lists:
        tot_df = pd.concat([tot_df,ll],axis=1)
    return tot_df

# %%
files = files[1:3]

# %%
files
# Out:
# ['Coinbase-52cf9509ca30a7c98a00003b-TaxTransactionsReport-2018-11-02-16_18_24.csv',
#  'coindesk-bpi-USD-close_data-2014-07-01_2014-07-02.csv']

# %%
df1 = pd.read_csv(baseDir + '/' +  files[0])
df2 = pd.read_csv(baseDir + '/' + files[1])

# %%
df1.head()
# Out:
#   Transactions                 Unnamed: 1                Unnamed: 2  \
# 0         User  cassetti.martha@gmail.com  52cf9509ca30a7c98a00003a
# 1          NaN                        NaN                       NaN
# 2    Timestamp           Transaction Type                     Asset
# 3       2/3/14                        Buy                       BTC
# 4      2/28/14                        Buy                       BTC
#
#             Unnamed: 3                     Unnamed: 4  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2  Quantity Transacted  USD Spot Price at Transaction
# 3                 0.02                         811.08
# 4                  0.5                         563.09
#
#                                           Unnamed: 5 Unnamed: 6  \
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# ...

# %%
df2.head()
# Out:
#                   Date  Close Price
# 0  2014-07-01 00:00:00       639.36
# 1  2014-07-01 00:01:00       639.80
# 2  2014-07-01 00:02:00       641.04
# 3  2014-07-01 00:03:00       641.94
# 4  2014-07-01 00:04:00       643.04

# %%
test = list_join(df1, df2)

# %%
df1.columns
# Out:
# Index(['Transactions', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14'],
#       dtype='object')

# %%
# Out:
# Index(['Date', 'Close Price'], dtype='object')

# %%
class SupremeBullShit:
    def __init__(self):
        pass
    def add_to_things(self, a, b):
        return a + b
class LameO:
    def __init__(self):
        self.bs = SupremeBullShit()
    def testMyShit(self, *dataframes):
        tot_df = pd.DataFrame()
        for df in dataframes:
            tot_df = pd.concat([tot_df, df],axis=1)
        return tot_df

# %%
lo = LameO()

# %%
lo.testMyShit(df1,df2)
# Out:
#      Transactions                 Unnamed: 1                Unnamed: 2  \
# 0            User  cassetti.martha@gmail.com  52cf9509ca30a7c98a00003a
# 1             NaN                        NaN                       NaN
# 2       Timestamp           Transaction Type                     Asset
# 3          2/3/14                        Buy                       BTC
# 4         2/28/14                        Buy                       BTC
# 5         2/28/14                        Buy                       BTC
# 6         2/28/14                        Buy                       BTC
# 7         2/28/14                       Send                       BTC
# 8          3/3/14                        Buy                       BTC
# 9          3/5/14                        Buy                       BTC
# 10         3/7/14                        Buy                       BTC
# 11        3/12/14                        Buy                       BTC
# ...
